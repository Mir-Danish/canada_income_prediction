# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("canada_income_dataset.csv")

# %%
df.head()
# Out:
#    year  percapitaincomeUS
# 0  1970        3399.299037
# 1  1971        3768.297935
# 2  1972        4251.175484
# 3  1973        4804.463248
# 4  1974        5576.514583

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('income US$')
plt.scatter(df.year,df.percapitaincomeUS)

# %%
regr = linear_model.LinearRegression()
regr.fit(df[['year']],df.percapitaincomeUS)
# Out:
# LinearRegression()

# %%
regr.predict([[2025]])
# Out:
# C:\Users\Danish\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([45431.01947053])

# %%
regr.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %%
regr.coef_
# Out:
# array([828.46507522])

# %%
#y=m*x+b
828.46507522*1995+-1632210.7578554575
# Out:
# 20577.067208442604
